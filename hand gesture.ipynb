# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\91934\anaconda\lib\site-packages (2.3.1)
# Requirement already satisfied: filelock in c:\users\91934\anaconda\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\91934\anaconda\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\91934\anaconda\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\91934\anaconda\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\91934\anaconda\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\91934\anaconda\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\91934\anaconda\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\91934\anaconda\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\91934\anaconda\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91934\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\91934\anaconda\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in c:\users\91934\anaconda\lib\site-packages (0.18.1)
# Requirement already satisfied: numpy in c:\users\91934\anaconda\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.3.1 in c:\users\91934\anaconda\lib\site-packages (from torchvision) (2.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\91934\anaconda\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: filelock in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (4.9.0)
# Requirement already satisfied: sympy in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (1.12)
# Requirement already satisfied: networkx in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\91934\anaconda\lib\site-packages (from torch==2.3.1->torchvision) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\91934\anaconda\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\91934\anaconda\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91934\anaconda\lib\site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\91934\anaconda\lib\site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm.notebook import tqdm
from torchvision import datasets, transforms, models 
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torch.utils.data import random_split
from torch.utils.data.dataloader import DataLoader
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_dir = r'C:\Users\91934\Desktop\test 3'
test_dir = r'C:\Users\91934\Desktop\train 3'
classes = os.listdir(train_dir)

# %%
train_transform=transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(40),              # resize shortest side
        transforms.CenterCrop(40),          # crop longest side
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
])

# %%
dataset = ImageFolder(train_dir, transform=train_transform)
testset = ImageFolder(test_dir, transform=train_transform)
print(len(dataset))
# Out:
# 2000

# %%
# function for the showing the image.
def show_image(img,label):
    print('Label: ', dataset.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1,2,0))

# %%
show_image(*dataset[6])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label:  01_palm (0)

# %%
torch.manual_seed(10)
val_size=len(dataset)//5
train_size=len(dataset) - val_size
train_ds, val_ds = random_split(dataset, [train_size, val_size])
test_ds = testset
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (1600, 400, 611)

# %%
batch_size = 64
train_loader = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_ds, batch_size*2, num_workers=4, pin_memory=True)

# %%
for images, labels in train_loader:
    fig, ax = plt.subplots(figsize=(18,10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(images,nrow=16).permute(1,2,0))
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
